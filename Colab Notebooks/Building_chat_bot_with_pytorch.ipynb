# %%
# !pip install pytorch
# Out:
# ...
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ...
#     Running setup.py install for pytorch ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-8vacvxza/pytorch_5b585cbb7e224493abf1fe22d757f642/setup.py'"'"'; __file__='"'"'/tmp/pip-install-8vacvxza/pytorch_5b585cbb7e224493abf1fe22d757f642/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-77wticqn/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7/pytorch Check the logs for full command output.

# %%
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F 
import csv
import random
import re
import os
import unicodedata
import codecs
import itertools

# %%
CUDA = torch.cuda.is_available()
device = torch.device("cuda" if CUDA else "cpu")

# %%
device
# Out:
# device(type='cpu')

# %%
lines_filepath = os.path.join
